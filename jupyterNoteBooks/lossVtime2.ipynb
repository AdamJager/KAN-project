# %%
import os, sys
import numpy as np
import torch
import matplotlib.pyplot as plt
module_path = os.path.abspath(os.path.join('..'))
sys.path.append(os.path.join(module_path, "KAN_variants"))
#from ChebyKANLayer import ChebyKAN
from efficientKAN import KAN
from fastkan import FastKAN
from ChebyKANLayerCopy import ChebyKAN as ChebyKAN2

module_path = os.path.abspath(os.path.join('..'))
sys.path.append(os.path.join(module_path, "code"))
from myKANODE import KANODE

# %%
def pred_prey_deriv(X, t, alpha, beta, delta, gamma):
    x=X[0]
    y=X[1]
    dxdt = alpha*x-beta*x*y
    dydt = delta*x*y-gamma*y
    dXdt=[dxdt, dydt]
    return dXdt

# alpha, beta, delta, gamma
params = [1.5, 1, 2, 1]
X0 = [0.1, 1.5]

# %%
def vanDerPoll(X, t, epsilon):
    x = X[0]
    y = X[1]
    dxdt = y
    dydt = epsilon*(1-x*x)*y - x
    return [dxdt, dydt]
vdpX0 = [0, 1.5]
vdpParams = [0.2]

# %%
t0 = 6
t1 = 20
model2 = ChebyKAN2([2, 10, 2], 4)
kanODE2 = KANODE(model2, pred_prey_deriv, X0, params, t1, t0, 0.01)
saveDirectory = os.path.join(module_path, "savedModels", "optimisedModel3")
kanODE2.loadModel(saveDirectory, "defaultName 9193")
# Out:
# c:\Users\Adam\Documents\GitHub\KAN-project\code\myKANODE.py:159: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model = torch.load(modelPath)
# c:\Users\Adam\Documents\GitHub\KAN-project\code\myKANODE.py:164: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.optimizer.load_state_dict(torch.load(optimizerPath))

# %%
_, solution = kanODE2.test(solverMethod="rk4")
loss = torch.square(solution[kanODE2.trainingSamples:,0, :]-kanODE2.baseSolution[kanODE2.trainingSamples:, :]).detach().cpu()
kanODE2.plotODE("ode and solution", solution[:, 0, :])
kanODE2.plotPhaseSpace("Phase Space", solution[:, 0, :])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 _, solution = kanODE2.test(solverMethod="rk4")
#       2 loss = torch.square(solution[kanODE2.trainingSamples:,0, :]-kanODE2.baseSolution[kanODE2.trainingSamples:, :]).detach().cpu()
#       3 kanODE2.plotODE("ode and solution", solution[:, 0, :])
#
# File c:\Users\Adam\Documents\GitHub\KAN-project\code\myKANODE.py:133, in KANODE.test(self, solverMethod, rtol, atol)
#     131 modelWrapper = lambda t, x: self.model(x)
#     132 self.model.eval()
# --> 133 prediction = torchodeint(modelWrapper, self.odeInitialState, self.time, rtol=rtol, atol=atol, method=solverMethod)
#     134 loss = torch.mean(torch.square(prediction[self.trainingSamples:,0, :]-self.baseSolution[self.trainingSamples:, :])).detach().cpu()
#     136 return loss, prediction
#
# File c:\Users\Adam\Documents\Python\Lib\site-packages\torchdiffeq\_impl\odeint.py:79, in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      76 solver = SOLVERS[method](func=func, y0=y0, rtol=rtol, atol=atol, **options)
#      78 if event_fn is None:
# ---> 79     solution = solver.integrate(t)
#      80 else:
#      81     event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# File c:\Users\Adam\Documents\Python\Lib\site-packages\torchdiffeq\_impl\solvers.py:114, in FixedGridODESolver.integrate(self, t)
#     112 dt = t1 - t0
#     113 self.func.callback_step(t0, y0, dt)
# --> 114 dy, f0 = self._step_func(self.func, t0, dt, t1, y0)
#     115 y1 = y0 + dy
#     117 while j < len(t) and t1 >= t[j]:
#
# File c:\Users\Adam\Documents\Python\Lib\site-packages\torchdiffeq\_impl\fixed_grid.py:28, in RK4._step_func(self, func, t0, dt, t1, y0)
#      27 def _step_func(self, func, t0, dt, t1, y0):
# ---> 28     f0 = func(t0, y0, perturb=Perturb.NEXT if self.perturb else Perturb.NONE)
#      29     return rk4_alt_step_func(func, t0, dt, t1, y0, f0=f0, perturb=self.perturb), f0
#
# File c:\Users\Adam\Documents\Python\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Adam\Documents\Python\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Adam\Documents\Python\Lib\site-packages\torchdiffeq\_impl\misc.py:197, in _PerturbFunc.forward(self, t, y, perturb)
#     194 else:
#     195     # Do nothing.
#     196     pass
# --> 197 return self.base_func(t, y)
#
# File c:\Users\Adam\Documents\GitHub\KAN-project\code\myKANODE.py:131, in KANODE.test.<locals>.<lambda>(t, x)
#     129 def test(self, solverMethod="dopri5", rtol=1e-7, atol=1e-9):
# --> 131     modelWrapper = lambda t, x: self.model(x)
#     132     self.model.eval()
#     133     prediction = torchodeint(modelWrapper, self.odeInitialState, self.time, rtol=rtol, atol=atol, method=solverMethod)
#
# File c:\Users\Adam\Documents\Python\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Adam\Documents\Python\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Adam\Documents\GitHub\KAN-project\KAN_variants\ChebyKANLayer.py:84, in ChebyKAN.forward(self, x)
#      82 def forward(self, x):
#      83     for layer, normLayer in zip(self.layers, self.normLayers):
# ---> 84         x = layer(x)
#      85         x = normLayer(x)
#      86     x = self.layers[-1](x)
#
# File c:\Users\Adam\Documents\Python\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Adam\Documents\Python\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Adam\Documents\GitHub\KAN-project\KAN_variants\ChebyKANLayer.py:21, in ChebyKANLayer.forward(self, x)
#      18 def forward(self, x):
#      19     # Since Chebyshev polynomial is defined in [-1, 1]
#      20     # We need to normalize x to [-1, 1] using tanh
# ---> 21     x = torch.tanh(self.alpha*x)
#      22     # View and repeat input degree + 1 times
#      23     x = x.view((-1, self.inputdim, 1)).expand(
#      24         -1, -1, self.degree + 1
#      25     )  # shape = (batch_size, inputdim, self.degree + 1)
#
# File c:\Users\Adam\Documents\Python\Lib\site-packages\torch\nn\modules\module.py:1931, in Module.__getattr__(self, name)
#    1929     if name in modules:
#    1930         return modules[name]
# -> 1931 raise AttributeError(
#    1932     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1933 )
#
# AttributeError: 'ChebyKANLayer' object has no attribute 'alpha'

# %%
time = torch.linspace(t0, t1, len(loss[:, 0]))
plt.plot(time, loss[:, 0])
plt.plot(time, loss[:, 1])
